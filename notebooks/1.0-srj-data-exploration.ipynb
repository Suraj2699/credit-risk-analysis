# %%
from src.data.make_dataset import get_data, handling_categories, handling_continuous_columns
from src.features.build_features import create_new_features
from src.visualization.visualize import visualize_categorical_bars, visualize_categorical_distributions, visualize_continuous_distributions, property_v_class_crossmap, correlation_matrix, purpose_v_class_crossmap, create_boxplots

# %%
df = get_data()

df.head()
# Out:
#   Attribute1  Attribute2 Attribute3 Attribute4  Attribute5 Attribute6  \
# 0        A11           6        A34        A43        1169        A65
# 1        A12          48        A32        A43        5951        A61
# 2        A14          12        A34        A46        2096        A61
# 3        A11          42        A32        A42        7882        A61
# 4        A11          24        A33        A40        4870        A61
#
#   Attribute7  Attribute8 Attribute9 Attribute10  ...  Attribute12 Attribute13  \
# 0        A75           4        A93        A101  ...         A121          67
# 1        A73           2        A92        A101  ...         A121          22
# 2        A74           2        A93        A101  ...         A121          49
# 3        A74           2        A93        A103  ...         A122          45
# 4        A73           3        A93        A101  ...         A124          53
#
# ...

# %%
## Check the Columns

df.columns
# Out:
# Index(['Attribute1', 'Attribute2', 'Attribute3', 'Attribute4', 'Attribute5',
#        'Attribute6', 'Attribute7', 'Attribute8', 'Attribute9', 'Attribute10',
#        'Attribute11', 'Attribute12', 'Attribute13', 'Attribute14',
#        'Attribute15', 'Attribute16', 'Attribute17', 'Attribute18',
#        'Attribute19', 'Attribute20', 'class'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 21)

# %%
## As we can see, the dataset has columns with categorical and continuous features.
## We will now handle the categorical features and continuous features separately.

# %%
# Let's use the function handling_categories to handle the categorical features.
# This function will convert the categorical features into numerical features using LabelEncoder.
# In the original dataset, class 1 represents good credit applicants and class 2 represents bad credit applicants.
# We will convert these classes into 0 and 1 respectively.

df = handling_categories(df)
df.head()
# Out:
# C:\Users\suraj\OneDrive\Desktop\Resume Projects\credit_risk_analysis\src\data\make_dataset.py:48: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['class'].replace({1: 0, 2:1}, inplace=True)
#    Existing-Checking-Account-Status  Duration(Months)  Credit-History  \
# 0                                 0                 6               4
# 1                                 1                48               2
# 2                                 3                12               4
# ...

# %%
## Now, it has become noticable that all the categorical features have been converted into numerical features.
## LabelEncoder converts the categorical features into numerical features by assigning a unique number to each category.
## For example, the categorical feature 'purpose' has been converted into numerical features as follows:
## 0: 'car(new)', 1: 'car(used)', 2: 'furniture/equipment', 3: 'radio/television', 4: 'domestic appliances', 5: 'repairs', 6: 'education', 7: 'retraining', 8: 'business', 9: 'others'

# %%
## Let's visualize the categorical features using the function visualize_categorical_bars.
# This function will plot the categorical features against its count.
# It will help us to understand the distribution of the categorical features with respect to uts their varied values.
visualize_categorical_bars(df)

# %%
## From the above plot, we can deduce that for the categorical feature 'Existing-Checking-Account-Status', the most common value for filing a loan application is 'No Checking Account.'
## For the categorical feature 'Purpose', the most common value is 'Domestic Appliances.'
## For the categorical feature 'Property', the most common value is 'No Property.'
## For the categorical feature 'Housing', the most common value is 'Owns a Home.'
## For the categorical feature 'Credit History', the most common value is 'Existing Credits Paid Back Duly Till Now.'
## For the categorical feature 'Savings Account/Bonds', the most common value is '<100 DM.'
## For the categorical feature 'Present Employment Status', the most common value is '1<= X < 4 years.'
## For the categorical feature 'Personal Status', the most common value is 'Male : Single.'
## For the categorical feature 'Telephone', the most common value is 'No Telephone.'

# %%
df.columns
# Out:
# Index(['Existing-Checking-Account-Status', 'Duration(Months)',
#        'Credit-History', 'Purpose', 'Credit-Amount', 'Savings-Account(Bonds)',
#        'Present-Employment-Since', 'Installment-Rate(%)',
#        'Personal-Status-Sex', 'Other-Debtors', 'Present-Residence-Since',
#        'Property', 'Age', 'Other-Installment-Plans', 'Housing',
#        'Bank-Existing-Credits', 'Job', 'Total-Reliable-People', 'Telephone',
#        'Foreign-Worker', 'class'],
#       dtype='object')

# %%
df['Present-Employment-Since'].value_counts()
# Out:
# Present-Employment-Since
# 2    339
# 4    253
# 3    174
# 1    172
# 0     62
# Name: count, dtype: int64

# %%
## Let's visualize the categorical features using the function visualize_categorical_distributions.
## This function will plot the categorical features against its distribution.
visualize_categorical_distributions(df)

# %%
## The above plot highlights the different values of the categorical features, along with their probability of good credit rate.
## For instance, a greater number of applicants have an 'Existing-Checking-Account-Status' as 'No Checking Account'.

# %%
## Compare property with class:
property_v_class_crossmap(df)

# %%
## The categorical feature 'Property' has a higher probability of good credit rate for the value 'Real Estate' and a lower probability for the value 'Unknown/No Property.'
## As the total approved loans are 222, the probability of good credit rate for the value 'Real Estate' is 0.78 (222/(222+60)) and for the value 'Unknown/No Property' is 0.56.

# %%
## Let's visualize purpose vs class crossmap.
purpose_v_class_crossmap(df)

# %%
## From the above plot, we can notice that there's a higher chance of getting a loan for the purpose of 'Business' with a prob of 89% (8/9) compared to the other purposes.
## We must carefully consider this aspect as the amount of data for "Business" is quite low.
## We've got a good probability (83%) of loan approval for the purpose of 'Car (used)' (86/103).
## And, a decent probability (78%) of loan approval for the purpose of 'Domestic Appliances' (218/280).

# %%
## Now, let's engineer two new features: Debt to Income Ratio and Credit Utilization Ratio. These features will help us to understand the creditworthiness of the applicants.
df = create_new_features(df)

# %%
df.head()
# Out:
#    Existing-Checking-Account-Status  Duration(Months)  Credit-History  \
# 0                                 0                 6               4
# 1                                 1                48               2
# 2                                 3                12               4
# 3                                 0                42               2
# 4                                 0                24               3
#
#    Purpose  Credit-Amount  Savings-Account(Bonds)  Present-Employment-Since  \
# 0        4           1169                       4                         4
# 1        4           5951                       0                         2
# 2        7           2096                       0                         3
# 3        3           7882                       0                         3
# 4        0           4870                       0                         2
#
#    Installment-Rate(%)  Personal-Status-Sex  Other-Debtors  ...  \
# ...

# %%
new_columns = ['Debt_to_Income_Ratio', 'Credit_Utilization']

df[new_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Debt_to_Income_Ratio  1000 non-null   float64
#  1   Credit_Utilization    1000 non-null   float64
# dtypes: float64(2)
# memory usage: 15.8 KB

# %%
df[new_columns].describe().T
# Out:
#                        count      mean       std     min      25%      50%  \
# Debt_to_Income_Ratio  1000.0  1.711853  1.916941  0.0845  0.60175  1.08375
# Credit_Utilization    1000.0  1.024967  0.685842  0.2000  0.40000  1.00000
#
#                           75%     max
# Debt_to_Income_Ratio  2.06325  15.945
# Credit_Utilization    1.00000   4.000

# %%
## We have five different continuous features in the dataset.

continuous_columns = ['Age', 'Credit-Amount', 'Duration(Months)', 'Debt_to_Income_Ratio', 'Credit_Utilization']

# %%
df[continuous_columns].describe().T
# Out:
#                        count         mean          std       min         25%  \
# Age                   1000.0    35.546000    11.375469   19.0000    27.00000
# Credit-Amount         1000.0  3271.258000  2822.736876  250.0000  1365.50000
# Duration(Months)      1000.0    20.903000    12.058814    4.0000    12.00000
# Debt_to_Income_Ratio  1000.0     1.711853     1.916941    0.0845     0.60175
# Credit_Utilization    1000.0     1.024967     0.685842    0.2000     0.40000
#
#                              50%         75%        max
# Age                     33.00000    42.00000     75.000
# Credit-Amount         2319.50000  3972.25000  18424.000
# Duration(Months)        18.00000    24.00000     72.000
# Debt_to_Income_Ratio     1.08375     2.06325     15.945
# Credit_Utilization       1.00000     1.00000      4.000

# %%
visualize_continuous_distributions(df)

# %%
## The above plot shows the distribution of the continuous features.
## For credit amount, the distribution is right skewed, and the most common value is around 0 to 2000.
## For duration, the distribution is right skewed, and the most common value is around 0 to 25 months.
## For age, the distribution is right skewed, and the most common value is around 20 to 40.
## For debt to income ratio, the distribution is right skewed, and the most common value is around 0 to 2.
## For credit utilization, the distribution is right skewed, and the most common value is 1.

# %%
## Let's visualize the boxplot to check the median, IQR, and outliers.

create_boxplots(df)

# %%
## The outliers are in an acceptable range. However, the skewness can affect the model performance.
## Let's handle the skewness in the continuous features using the function handling_continuous_columns.

# %%
df, lambda1, lambda2, lambda3, lambda4, lambda5 = handling_continuous_columns(df)

# %%
df[continuous_columns].describe().T
# Out:
#                        count      mean       std       min       25%  \
# Age                   1000.0  1.303740  0.023465  1.249817  1.286335
# Credit-Amount         1000.0  6.109451  0.468529  4.647138  5.770557
# Duration(Months)      1000.0  3.129856  0.615242  1.662995  2.702766
# Debt_to_Income_Ratio  1000.0  0.552886  0.221933  0.078367  0.387708
# Credit_Utilization    1000.0  0.555029  0.244821  0.175606  0.314073
#
#                            50%       75%       max
# Age                   1.303796  1.321968  1.355375
# Credit-Amount         6.097139  6.417587  7.272845
# Duration(Months)      3.127002  3.437882  4.685365
# Debt_to_Income_Ratio  0.545114  0.720226  1.064823
# Credit_Utilization    0.602504  0.602504  1.174633

# %%
## It is clearly observable that the maximum value of the continuous features has been reduced.
## The skewness has been reduced to a great extent.
df[continuous_columns].skew().T
# Out:
# Age                     0.056496
# Credit-Amount           0.005453
# Duration(Months)       -0.004345
# Debt_to_Income_Ratio    0.128454
# Credit_Utilization      0.040640
# dtype: float64

# %%
## The skewness is significantly reduced for all the continuous features.
## It is now in an acceptable range.

# %%
## Now, we can visualize the continuous features again to check the distribution of the continuous features after handling the skewness.
visualize_continuous_distributions(df)

# %%
## After handling the skewness, we can now create a correlation matrix to check the correlation between the features.
correlation_matrix(df)
